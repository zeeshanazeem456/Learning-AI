# %% [markdown]
# ## Name: Zeeshan | Session= 2

# %%
def division(a,b):
    try:
        result = a / b
    except ZeroDivisionError:
        print("The Divider can't be Zero!")
        return None
    except TypeError:
        print("The Datatypes should be number!")
        return None
    else:
        print("Division Successfull")
        return result

print(division(9,3))
# Out:
# Division Successfull
# 3.0

# %% [markdown]
# - List

# %%
list = ["banana","apple"]
list.append("grapes")
for i in list:
    print(i)
# Out:
# banana
# apple
# grapes

# %% [markdown]
# - Task 1

# %%
contacts = [
    {"name": "Ali", "email": "Ali@gmail.com", "phone": "123"},
    {"name": "Ahmed", "email": "ahmed@gmail.com", "phone": "456"},
]

def clean_contacts(contacts):
    seen = set()
    unique_contacts = []
    lookup = {}
    for contact in contacts:
        email = contact["email"].lower().strip()
        if email in seen:
            continue
        seen.add(email)
        unique_contacts.append(contact)
        lookup[email] = contact
    return unique_contacts, lookup


def get_contact(email):
    email = email.lower().strip()
    return lookup.get(email)

unique_contacts, lookup = clean_contacts(contacts)

print(get_contact("ALI@GMAIL.COM"))
print(get_contact("unknown@GMAIL.COM"))
# Out:
# {'name': 'Ali', 'email': 'Ali@gmail.com', 'phone': '123'}
# None
